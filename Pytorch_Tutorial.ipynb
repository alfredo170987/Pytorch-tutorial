# %% [markdown]
# <a href="https://colab.research.google.com/github/alfredo170987/Pytorch-tutorial/blob/main/Pytorch_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
